# %%
import pandas as pd
import numpy as np

import requests

import sys
import os

# %%
df_deputados = pd.read_csv('../data/tb_deputados.csv')
df_deputados
# Out:
#          id                                                uri  \
# 0    204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1    220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2    221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3    204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4    204528  https://dadosabertos.camara.leg.br/api/v2/depu...
# ..      ...                                                ...
# 507  220558  https://dadosabertos.camara.leg.br/api/v2/depu...
# 508  204517  https://dadosabertos.camara.leg.br/api/v2/depu...
# 509  160592  https://dadosabertos.camara.leg.br/api/v2/depu...
# 510  220592  https://dadosabertos.camara.leg.br/api/v2/depu...
# 511  220552  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nome  siglaPartido  \
# 0     Acácio Favacho           MDB
# 1        Adail Filho  REPUBLICANOS
# 2    Adilson Barroso            PL
# 3       Adolfo Viana          PSDB
# ...

# %%
df_deputados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             512 non-null    int64
#  1   uri            512 non-null    object
#  2   nome           512 non-null    object
#  3   siglaPartido   512 non-null    object
#  4   uriPartido     512 non-null    object
#  5   siglaUf        512 non-null    object
#  6   idLegislatura  512 non-null    int64
#  7   urlFoto        512 non-null    object
#  8   email          512 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 36.1+ KB
