# %%
import pandas as pd
import numpy as np

import requests

import sys
import os

# %%
# Caminho para a raiz do projeto
root_path = os.path.abspath("..")  # sobe um nível (de notebooks/ para raiz)
if root_path not in sys.path:
    sys.path.append(root_path)

# importa a classe
from src.api.deputados_api import deputadoAPI

# %%
# cria a instância da API
api = deputadoAPI(base_url='https://dadosabertos.camara.leg.br/api/v2/')

# requisitar os dados
dados = api.get_dados(endpoint='deputados')
dados.keys()

dados = dados['dados']
dados
df = pd.DataFrame(dados)
df.head()

df.to_csv('../data/tb_deputados.csv', index=False)

# %%
df_deputados = pd.read_csv('../data/tb_deputados.csv')
df_deputados
# Out:
#          id                                                uri  \
# 0    204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1    220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2    221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3    204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4    204528  https://dadosabertos.camara.leg.br/api/v2/depu...
# ..      ...                                                ...
# 508  220558  https://dadosabertos.camara.leg.br/api/v2/depu...
# 509  204517  https://dadosabertos.camara.leg.br/api/v2/depu...
# 510  160592  https://dadosabertos.camara.leg.br/api/v2/depu...
# 511  220592  https://dadosabertos.camara.leg.br/api/v2/depu...
# 512  220552  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                 nome  siglaPartido  \
# 0     Acácio Favacho           MDB
# 1        Adail Filho  REPUBLICANOS
# 2    Adilson Barroso            PL
# 3       Adolfo Viana          PSDB
# ...

# %%
df_deputados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             513 non-null    int64
#  1   uri            513 non-null    object
#  2   nome           513 non-null    object
#  3   siglaPartido   513 non-null    object
#  4   uriPartido     513 non-null    object
#  5   siglaUf        513 non-null    object
#  6   idLegislatura  513 non-null    int64
#  7   urlFoto        513 non-null    object
#  8   email          513 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 36.2+ KB

# %%
coluna_id = list(df_deputados['id'])
deputados_informacoes = {}

for x in coluna_id:
    print(x)

# requisitar os dados
    dados = api.get_dados(endpoint=f'deputados/{x}')
    dados.keys()

    dados = dados['dados']
    deputados_informacoes[dados['id']] = dados






deputados_informacoes
# Out:
# 204379
# 220714
# 221328
# 204560
# 204528
# 121948
# 74646
# 136811
# 178835
# 160527
# 204495
# 204549
# 73579
# 220538
# 160559
# 204501
# 178972
# 204571
# 220542
# 220554
# 221148
# 220576
# 74057
# 178927
# 226708
# 178937
# 178881
# 220707
# 204356
# 220715
# 107970
# 220556
# 220632
# 220657
# 204423
# 133439
# 204515
# 220676
# 123756
# 220544
# 160553
# 220638
# 220675
# 220549
# 73433
# 141391
# 160541
# 160600
# 74090
# 123086
# 160665
# 220577
# 160512
# 69871
# 178975
# 220605
# 220612
# 73701
# 109429
# 204358
# 220683
# 204374
# 204388
# 160538
# 210989
# 220635
# 220574
# 143942
# 220548
# 204572
# 220690
# 178829
# 213762
# 204507
# 178993
# 204460
# 74262
# 204426
# 141398
# 220704
# 204369
# 220699
# 206018
# 178876
# 204488
# 73441
# 204504
# 205476
# 74171
# 204476
# 204462
# 220665
# 74537
# 141408
# 88256
# 98148
# 220594
# 204378
# 220595
# 220666
# 220590
# 178963
# 220608
# 204355
# 141411
# 220555
# 220692
# 74467
# 220629
# 220603
# 220571
# 74060
# ...

# %%
deputados_informacoes = pd.DataFrame(deputados_informacoes)
deputados_informacoes = deputados_informacoes.T

deputados_informacoes.head()
# Out:
#             id                                                uri  \
# 204379  204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 220714  220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 221328  221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 204560  204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# 204528  204528  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                              nomeCivil  \
# 204379    ACÁCIO DA SILVA FAVACHO NETO
# 220714  ADAIL JOSÉ FIGUEIREDO PINHEIRO
# 221328        ADILSON BARROSO OLIVEIRA
# 204560     ADOLFO VIANA DE CASTRO NETO
# 204528          ADRIANA MIGUEL VENTURA
#
#                                              ultimoStatus          cpf sexo  \
# 204379  {'id': 204379, 'uri': 'https://dadosabertos.ca...  74287028287    M
# 220714  {'id': 220714, 'uri': 'https://dadosabertos.ca...  77267796249    M
# 221328  {'id': 221328, 'uri': 'https://dadosabertos.ca...  05585378805    M
# ...

# %%
deputados_informacoes.reset_index(drop=True, inplace=True)
deputados_informacoes.head()
# deputados_informacoes = deputados_informacoes.drop(columns=['uri','ultimoStatus',  ])
# Out:
#        id                       nomeCivil  \
# 0  204379    ACÁCIO DA SILVA FAVACHO NETO
# 1  220714  ADAIL JOSÉ FIGUEIREDO PINHEIRO
# 2  221328        ADILSON BARROSO OLIVEIRA
# 3  204560     ADOLFO VIANA DE CASTRO NETO
# 4  204528          ADRIANA MIGUEL VENTURA
#
#                                         ultimoStatus          cpf sexo  \
# 0  {'id': 204379, 'uri': 'https://dadosabertos.ca...  74287028287    M
# 1  {'id': 220714, 'uri': 'https://dadosabertos.ca...  77267796249    M
# 2  {'id': 221328, 'uri': 'https://dadosabertos.ca...  05585378805    M
# 3  {'id': 204560, 'uri': 'https://dadosabertos.ca...  80123848504    M
# 4  {'id': 204528, 'uri': 'https://dadosabertos.ca...  12519851813    F
#
#   urlWebsite                                         redeSocial  \
# 0       None  [https://twitter.com/acaciofavacho, https://ww...
# 1       None  [https://twitter.com/adailfilhoam?s=21&t=O_eoT...
# 2       None                                                 []
# ...

# %%
deputados_informacoes['escolaridade'].value_counts()
# Out:
# escolaridade
# Superior                   287
# Pós-Graduação               74
# Superior Incompleto         39
# Mestrado                    34
# Ensino Médio                26
# Doutorado                   11
# Ensino Fundamental          11
# Mestrado Incompleto          7
# Doutorado Incompleto         6
# Ensino Médio Incompleto      3
# Secundário                   2
# Primário Incompleto          1
# Secundário Incompleto        1
# Name: count, dtype: int64
