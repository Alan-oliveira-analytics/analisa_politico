# %% [markdown]
# Objetivo aqui
#
# - Tratar os dados (remoção de colunas desnecessárias, padronização)
# - Juntar os arquivos (merge)
# - Retornar um csv tratado e pronto para as análises

# %%
import pandas as pd
import numpy as np

# %%
# lendo as bases

df_deputados = pd.read_csv('../data/tb_deputados.csv')
df_info_deputados = pd.read_csv('../data/info_deputados.csv')
df_despesas = pd.read_csv('../data/despesas_deputados.csv')

# %%
df_info_deputados.drop(columns=['Unnamed: 0'], inplace=True)
df_info_deputados.head()
# Out:
#        id                       nomeCivil          cpf sexo dataNascimento  \
# 0  204379    ACÁCIO DA SILVA FAVACHO NETO  74287028287    M     1983-09-28
# 1  220714  ADAIL JOSÉ FIGUEIREDO PINHEIRO  77267796249    M     1992-02-16
# 2  221328        ADILSON BARROSO OLIVEIRA   5585378805    M     1964-06-14
# 3  204560     ADOLFO VIANA DE CASTRO NETO  80123848504    M     1981-02-02
# 4  204528          ADRIANA MIGUEL VENTURA  12519851813    F     1969-03-06
#
#   ufNascimento municipioNascimento         escolaridade
# 0           AP              Macapá             Superior
# 1           AM              Manaus  Superior Incompleto
# 2           MG         Minas Novas             Superior
# 3           BA            Salvador             Superior
# 4           SP           São Paulo            Doutorado

# %%
df_deputados.drop(columns=['uri', 'uriPartido'], inplace=True)
df_deputados.head()
# Out:
#        id             nome  siglaPartido siglaUf  idLegislatura  \
# 0  204379   Acácio Favacho           MDB      AP             57
# 1  220714      Adail Filho  REPUBLICANOS      AM             57
# 2  221328  Adilson Barroso            PL      SP             57
# 3  204560     Adolfo Viana          PSDB      BA             57
# 4  204528  Adriana Ventura          NOVO      SP             57
#
#                                              urlFoto  \
# 0  https://www.camara.leg.br/internet/deputado/ba...
# 1  https://www.camara.leg.br/internet/deputado/ba...
# 2  https://www.camara.leg.br/internet/deputado/ba...
# 3  https://www.camara.leg.br/internet/deputado/ba...
# 4  https://www.camara.leg.br/internet/deputado/ba...
#
#                               email
# 0   dep.acaciofavacho@camara.leg.br
# 1      dep.adailfilho@camara.leg.br
# 2  dep.adilsonbarroso@camara.leg.br
# 3     dep.adolfoviana@camara.leg.br
# 4  dep.adrianaventura@camara.leg.br

# %%
df_despesas.drop(columns=['Unnamed: 0'], inplace=True)
df_despesas.rename(columns={'indice': 'id'}, inplace=True)
df_despesas.head()
# Out:
#       ano   mes                                        tipoDespesa  \
# 0  2024.0  11.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1  2024.0  12.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2  2024.0  11.0                      COMBUSTÍVEIS E LUBRIFICANTES.
# 3  2024.0  11.0                      COMBUSTÍVEIS E LUBRIFICANTES.
# 4  2024.0  11.0                      COMBUSTÍVEIS E LUBRIFICANTES.
#
#    codDocumento           tipoDocumento  codTipoDocumento  \
# 0     7837655.0             Nota Fiscal               0.0
# 1     7838902.0             Nota Fiscal               0.0
# 2     7833232.0  Nota Fiscal Eletrônica               4.0
# 3     7833238.0  Nota Fiscal Eletrônica               4.0
# 4     7833235.0  Nota Fiscal Eletrônica               4.0
#
#          dataDocumento numDocumento  valorDocumento  \
# 0  2024-11-06T00:00:00         1735          750.00
# 1  2024-12-03T00:00:00         1806          750.00
# 2  2024-11-12T14:48:43       432734          333.12
# 3  2024-11-14T17:52:07       433490          300.00
# 4  2024-11-19T19:56:23       434554          330.30
#
#                                         urlDocumento  \
# 0  https://www.camara.leg.br/cota-parlamentar/doc...
# 1  https://www.camara.leg.br/cota-parlamentar/doc...
# 2  http://www.camara.leg.br/cota-parlamentar/nota...
# 3  http://www.camara.leg.br/cota-parlamentar/nota...
# 4  http://www.camara.leg.br/cota-parlamentar/nota...
#
#                                       nomeFornecedor  cnpjCpfFornecedor  \
# 0                       AMORETTO CAFES EXPRESSO LTDA       8.532429e+12
# 1                       AMORETTO CAFES EXPRESSO LTDA       8.532429e+12
# 2  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
# 3  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
# 4  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
#
#    valorLiquido  valorGlosa  numRessarcimento    codLote  parcela      id
# 0        750.00         0.0               NaN  2092841.0      0.0  204379
# 1        750.00         0.0               NaN  2093592.0      0.0  204379
# 2        333.12         0.0               NaN  2090590.0      0.0  204379
# 3        300.00         0.0               NaN  2090590.0      0.0  204379
# 4        330.30         0.0               NaN  2090590.0      0.0  204379

# %%
# Reorganizando as colunas para colocar 'id' na primeira posição
cols = ['id'] + [col for col in df_despesas.columns if col != 'id']
df_despesas = df_despesas[cols]
df_despesas.head()
# Out:
#        id     ano   mes                                        tipoDespesa  \
# 0  204379  2024.0  11.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1  204379  2024.0  12.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2  204379  2024.0  11.0                      COMBUSTÍVEIS E LUBRIFICANTES.
# 3  204379  2024.0  11.0                      COMBUSTÍVEIS E LUBRIFICANTES.
# 4  204379  2024.0  11.0                      COMBUSTÍVEIS E LUBRIFICANTES.
#
#    codDocumento           tipoDocumento  codTipoDocumento  \
# 0     7837655.0             Nota Fiscal               0.0
# 1     7838902.0             Nota Fiscal               0.0
# 2     7833232.0  Nota Fiscal Eletrônica               4.0
# 3     7833238.0  Nota Fiscal Eletrônica               4.0
# 4     7833235.0  Nota Fiscal Eletrônica               4.0
#
#          dataDocumento numDocumento  valorDocumento  \
# 0  2024-11-06T00:00:00         1735          750.00
# 1  2024-12-03T00:00:00         1806          750.00
# 2  2024-11-12T14:48:43       432734          333.12
# 3  2024-11-14T17:52:07       433490          300.00
# 4  2024-11-19T19:56:23       434554          330.30
#
#                                         urlDocumento  \
# 0  https://www.camara.leg.br/cota-parlamentar/doc...
# 1  https://www.camara.leg.br/cota-parlamentar/doc...
# 2  http://www.camara.leg.br/cota-parlamentar/nota...
# 3  http://www.camara.leg.br/cota-parlamentar/nota...
# 4  http://www.camara.leg.br/cota-parlamentar/nota...
#
#                                       nomeFornecedor  cnpjCpfFornecedor  \
# 0                       AMORETTO CAFES EXPRESSO LTDA       8.532429e+12
# 1                       AMORETTO CAFES EXPRESSO LTDA       8.532429e+12
# 2  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
# 3  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
# 4  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
#
#    valorLiquido  valorGlosa  numRessarcimento    codLote  parcela
# 0        750.00         0.0               NaN  2092841.0      0.0
# 1        750.00         0.0               NaN  2093592.0      0.0
# 2        333.12         0.0               NaN  2090590.0      0.0
# 3        300.00         0.0               NaN  2090590.0      0.0
# 4        330.30         0.0               NaN  2090590.0      0.0

# %% [markdown]
# Unindo bases

# %%
df = pd.merge(df_deputados, df_info_deputados, on='id', how='right')
df.head()
# Out:
#        id             nome  siglaPartido siglaUf  idLegislatura  \
# 0  204379   Acácio Favacho           MDB      AP             57
# 1  220714      Adail Filho  REPUBLICANOS      AM             57
# 2  221328  Adilson Barroso            PL      SP             57
# 3  204560     Adolfo Viana          PSDB      BA             57
# 4  204528  Adriana Ventura          NOVO      SP             57
#
#                                              urlFoto  \
# 0  https://www.camara.leg.br/internet/deputado/ba...
# 1  https://www.camara.leg.br/internet/deputado/ba...
# 2  https://www.camara.leg.br/internet/deputado/ba...
# 3  https://www.camara.leg.br/internet/deputado/ba...
# 4  https://www.camara.leg.br/internet/deputado/ba...
#
#                               email                       nomeCivil  \
# 0   dep.acaciofavacho@camara.leg.br    ACÁCIO DA SILVA FAVACHO NETO
# 1      dep.adailfilho@camara.leg.br  ADAIL JOSÉ FIGUEIREDO PINHEIRO
# 2  dep.adilsonbarroso@camara.leg.br        ADILSON BARROSO OLIVEIRA
# 3     dep.adolfoviana@camara.leg.br     ADOLFO VIANA DE CASTRO NETO
# 4  dep.adrianaventura@camara.leg.br          ADRIANA MIGUEL VENTURA
#
#            cpf sexo dataNascimento ufNascimento municipioNascimento  \
# 0  74287028287    M     1983-09-28           AP              Macapá
# 1  77267796249    M     1992-02-16           AM              Manaus
# 2   5585378805    M     1964-06-14           MG         Minas Novas
# 3  80123848504    M     1981-02-02           BA            Salvador
# 4  12519851813    F     1969-03-06           SP           São Paulo
#
#           escolaridade
# 0             Superior
# 1  Superior Incompleto
# 2             Superior
# 3             Superior
# 4            Doutorado

# %%
df = pd.merge(df, df_despesas, on='id', how='right')
df.head()
# Out:
#        id            nome siglaPartido siglaUf  idLegislatura  \
# 0  204379  Acácio Favacho          MDB      AP             57
# 1  204379  Acácio Favacho          MDB      AP             57
# 2  204379  Acácio Favacho          MDB      AP             57
# 3  204379  Acácio Favacho          MDB      AP             57
# 4  204379  Acácio Favacho          MDB      AP             57
#
#                                              urlFoto  \
# 0  https://www.camara.leg.br/internet/deputado/ba...
# 1  https://www.camara.leg.br/internet/deputado/ba...
# 2  https://www.camara.leg.br/internet/deputado/ba...
# 3  https://www.camara.leg.br/internet/deputado/ba...
# 4  https://www.camara.leg.br/internet/deputado/ba...
#
#                              email                     nomeCivil          cpf  \
# 0  dep.acaciofavacho@camara.leg.br  ACÁCIO DA SILVA FAVACHO NETO  74287028287
# 1  dep.acaciofavacho@camara.leg.br  ACÁCIO DA SILVA FAVACHO NETO  74287028287
# 2  dep.acaciofavacho@camara.leg.br  ACÁCIO DA SILVA FAVACHO NETO  74287028287
# 3  dep.acaciofavacho@camara.leg.br  ACÁCIO DA SILVA FAVACHO NETO  74287028287
# 4  dep.acaciofavacho@camara.leg.br  ACÁCIO DA SILVA FAVACHO NETO  74287028287
#
#   sexo  ... numDocumento valorDocumento  \
# 0    M  ...         1735         750.00
# 1    M  ...         1806         750.00
# 2    M  ...       432734         333.12
# 3    M  ...       433490         300.00
# 4    M  ...       434554         330.30
#
#                                         urlDocumento  \
# 0  https://www.camara.leg.br/cota-parlamentar/doc...
# 1  https://www.camara.leg.br/cota-parlamentar/doc...
# 2  http://www.camara.leg.br/cota-parlamentar/nota...
# 3  http://www.camara.leg.br/cota-parlamentar/nota...
# 4  http://www.camara.leg.br/cota-parlamentar/nota...
#
#                                       nomeFornecedor  cnpjCpfFornecedor  \
# 0                       AMORETTO CAFES EXPRESSO LTDA       8.532429e+12
# 1                       AMORETTO CAFES EXPRESSO LTDA       8.532429e+12
# 2  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
# 3  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
# 4  031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEI...       3.065970e+11
#
#    valorLiquido valorGlosa  numRessarcimento    codLote  parcela
# 0        750.00        0.0               NaN  2092841.0      0.0
# 1        750.00        0.0               NaN  2093592.0      0.0
# 2        333.12        0.0               NaN  2090590.0      0.0
# 3        300.00        0.0               NaN  2090590.0      0.0
# 4        330.30        0.0               NaN  2090590.0      0.0
#
# [5 rows x 31 columns]

# %%
df.to_csv('../data/df_deputados.csv')
